# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“JUDUL MODUL PRAKTIKUM”**
#
# **Disusun Oleh :**
#
# **Fathimah Syahida El-Athira**
#
# **2611531005**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Avero**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Pertemuan 1 (Pengenalan Python, VSCode dan koneksi ke GitHub) yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Algoritma dan Pemograman. Praktikum ini berfokus pada pengenalan aplikasi Python, VSCode dan juga koneksi ke GitHub.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung Proses pembuatan kode program menggunakan Python di VSCode dan mengelola repositori proyek melalui GitHub pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, Sabtu 5 September 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Pengembangan perangkat lunak saat ini menuntut alur kerja yang efisien, rapi, dan terstruktur. Bahasa Python menjadi fondasi penting untuk dipelajari karena sintaksnya yang sederhana namun fleksibel untuk berbagai kebutuhan program. Untuk mendukung proses pengodean, penggunaan editor seperti Visual Studio Code (VSCode) sangat membantu dalam mempermudah penulisan, eksekusi, serta pelacakan kesalahan (debugging) kode dalam satu lingkungan kerja yang praktis.
# Selain penulisan kode, pengelolaan riwayat perubahan program dan penyimpanan berkas proyek secara aman juga menjadi bagian penting dalam pemrograman. Melalui integrasi dengan GitHub, berkas program dapat tersimpan dengan rapi di cloud sekaligus memudahkan pelacakan revisi dan kolaborasi. Praktikum ini dilakukan untuk memberikan pemahaman dasar mengenai pengoperasian Python pada VSCode hingga terhubung dengan repositori GitHub sebagai bentuk alur kerja pemrograman yang standar.
#
# ## 1.2 Tujuan
# 1. Memahami dasar-dasar bahasa pemograman dan cara menjalankan skrip program.
# 2. Mampu menggunakan Visual Studio Code (VS Code) sebagai lingkungan pengembangan untuk Python.
# 3. Mampu melakukan inisialisasi Git serta menghubungkan proyek lokal di VS Code ke repository GitHub.
#
# ## 1.3 Manfaat
# 1. Memudahkan dalam menulis, menjalankan, dan melakukan debugging skrip Python secara terstruktur menggunakan VS Code.
# 2. Membantu menyimpan riwayat perubahan proyek secara aman di cloud menggunakan repositori GitHub.
# 3. Membekali pemahaman tentang alur kerja pengembangan perangkat lunak berbasis version control yang standar.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Tuliskan penjelasan konsep/teori yang mendasari praktikum ini (definisi, elemen-elemen penting, dsb). Bisa memakai poin bernomor untuk merinci sub-konsep, contoh:
#
# 1. Python merupakan bahasa pemrograman tingkat tinggi yang memiliki sifat interpreted dan open-source. Keunggulan utamanya terletak pada sintaks yang ringkas dan mudah dipahami, sehingga mempercepat proses penulisan logika program. Python banyak diterapkan dalam pengembangan sistem, analisis data, pembuatan skrip otomatisasi, hingga pengembangan kecerdasan buatan.
# 2. Visual Studio Code adalah editor kode berbasis Integrated Development Environment (IDE) yang dikembangkan oleh Microsoft. Perangkat lunak ini memiliki performa yang ringan serta fleksibel karena didukung oleh ekosistem ekstensi yang luas. Fitur seperti terminal terintegrasi, pemindai kesalahan (debugging), dan syntax highlighting membantu memperlancar proses eksekusi kode Python.
# 3. GitHub merupakan platform berbasis web yang berfungsi sebagai tempat penyimpanan repositori berkas program menggunakan sistem Git. Platform ini digunakan untuk mencatat setiap riwayat perubahan kode (version control), menjaga keamanan salinan proyek di cloud, serta mendukung alur kerja kolaborasi antar-pengembang.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "C_2611531005"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Program pertama
"""
Komentar
dua baris atau lebih
pertemuan 1 pratikum alpro
"""
print("Hello wordl")
print()
print("Program ini menghasilkan")
print("Empat baris output")
print("/ \\ // \\\\ /// \\\\\\")
print("program ini" + "dibuat oleh a/n"
"Fathimah Syahida El-Athira dan 2611531005")
# Out:
# Hello wordl
#
# Program ini menghasilkan
# Empat baris output
# / \ // \\ /// \\\
# program inidibuat oleh a/nFathimah Syahida El-Athira dan 2611531005

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama sampai keenam sebagai penjelas sebuah struktur program.
#
# 2. Bagian ketujuh sampai terakhir menghasilkan output.
#
# 3. Program ini dijalankan dengan bahasa python.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python, VS Code, Git, dan GitHub memiliki fungsi yang saling berkaitan dalam proses pembuatan dan pengelolaan suatu program. Python digunakan sebagai bahasa pemrograman untuk membuat program, sedangkan VS Code digunakan untuk menulis dan menjalankan program. Git dan GitHub digunakan untuk mencatat perubahan serta menyimpan hasil pekerjaan. Praktikum ini menerapkan beberapa konsep dasar, seperti interpreter, repository, commit, push, dan clone. Pemahaman terhadap konsep tersebut membantu mahasiswa mengetahui tahapan dalam membuat, menyimpan, dan mengelola suatu program. Sehingga, praktikum ini dapat menjadi dasar dalam melaksanakan kegiatan pemrograman dan pengembangan proyek pada praktikum selanjutnya.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
# [1] Python Software Foundation. (2024). Python 3 Documentation. Python Software Found
#
# [2] Microsoft. (2024). Visual Studio Code Documentation. Microsoft.
#
# [3] Chacon, S., & Straub, B. (2014). Pro Git (2nd ed.). Apress.
