# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
#
# **"CONDITIONAL PADA PYTHON"**
#
# **Disusun Oleh :**
#
# **Fathimah Syahida El-Athira**
#
# **2611531005**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Avero**
#
# <br>
#
#  <img src="https://upload.wikimedia.org/wikipedia/commons/0/01/Logo_Unand.svg?utm_source=id.wikipedia.org&utm_campaign=index&utm_content=original" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Pertemuan 4 (Conditional pada python) yang telah dilaksanakan sebagai pertemuan ke-4 untuk mata kuliah Praktikum Algoritma dan Pemograman. Praktikum ini berfokus pada pengenalan dan cara penggunaan fungsi berdasarkan kondisi diantaranya seperti: if, multi if, if else, elif dan match case.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung Penggunaan Berbagai fungsi yang akan digunakan saat ada kondisi tertentu pada program.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 25 September 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Dalam dunia pemrograman, struktur kontrol percabangan merupakan salah satu konsep fundamental yang wajib dikuasai oleh setiap programmer. Struktur percabangan memungkinkan sebuah program untuk mengambil keputusan dan mengeksekusi blok kode tertentu berdasarkan suatu kondisi yang telah ditentukan. Tanpa adanya struktur percabangan, sebuah program hanya akan berjalan secara linear dari atas ke bawah tanpa mampu merespons berbagai kemungkinan input maupun kondisi yang berbeda-beda dari pengguna.
#
# Bahasa pemrograman Python menyediakan beberapa bentuk struktur percabangan, di antaranya pernyataan if tunggal, if-else, if-elif-else, penggunaan beberapa pernyataan if secara berurutan (multiple if), hingga pernyataan match-case yang diperkenalkan pada Python versi 3.11.9 sebagai alternatif dari switch-case pada bahasa pemrograman lain. Setiap bentuk percabangan tersebut memiliki karakteristik, kegunaan, dan konteks penerapan yang berbeda-beda tergantung pada permasalahan yang ingin diselesaikan.
#
# Melalui praktikum ini, mahasiswa dilatih untuk mengimplementasikan berbagai bentuk struktur percabangan tersebut ke dalam studi kasus nyata, seperti pengecekan kelulusan berdasarkan IPK, penentuan syarat mengendarai motor berdasarkan umur dan kepemilikan SIM, penentuan nama bulan, perhitungan diskon belanja, serta penentuan grade nilai mahasiswa. Dengan mempraktikkan langsung berbagai kasus tersebut, mahasiswa diharapkan mampu memahami perbedaan logika serta efisiensi dari masing-masing bentuk percabangan.
#
#
# ## 1.2 Tujuan
# 1. Memahami konsep dasar struktur kontrol percabangan pada bahasa pemrograman Python.
#
# 2. Mampu mengimplementasikan pernyataan if tunggal dan if-else untuk menyelesaikan permasalahan sederhana.
#
# 3. Mampu mengimplementasikan pernyataan if-elif-else untuk menangani lebih dari dua kemungkinan kondisi.
#
# 4. Mampu membedakan penggunaan if-elif-else dengan penggunaan beberapa pernyataan if (multiple if) yang berdiri sendiri, beserta dampaknya terhadap hasil eksekusi program.
#
# 5. Mampu mengimplementasikan pernyataan match-case sebagai alternatif percabangan berbasis pencocokan pola (pattern matching).
#
# 6. Mampu menerapkan operator logika (and) dalam kombinasi dengan struktur percabangan untuk mengevaluasi lebih dari satu kondisi sekaligus.
#
# ## 1.3 Manfaat
# 1. Mahasiswa dapat menyelesaikan permasalahan logika sederhana hingga kompleks menggunakan struktur percabangan pada Python.
#
# 2. Mahasiswa memperoleh pengalaman langsung dalam menulis, menjalankan, dan menganalisis output dari program yang melibatkan struktur percabangan.
#
# 3. Mahasiswa memahami kapan sebaiknya menggunakan if-elif-else dan kapan sebaiknya menggunakan multiple if, sesuai dengan kebutuhan logika program.
#
# 4. Hasil praktikum dapat dijadikan bekal dalam menyelesaikan studi kasus pemrograman yang lebih kompleks pada pertemuan-pertemuan berikutnya.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Percabangan (branching/selection) adalah struktur kontrol yang digunakan untuk memilih blok kode yang akan dieksekusi berdasarkan hasil evaluasi suatu kondisi logika (boolean). Berikut adalah bentuk-bentuk struktur percabangan yang digunakan dalam praktikum ini.
#
#  a. Pernyataan if tunggal — digunakan ketika hanya ada satu blok kode yang perlu dijalankan apabila suatu kondisi bernilai benar (True). Jika kondisi bernilai salah (False), blok kode di dalam if akan dilewati begitu saja.
#
#  b. Pernyataan if-else — digunakan ketika terdapat dua kemungkinan hasil, yaitu satu blok kode dijalankan apabila kondisi bernilai True, dan blok kode lain (di dalam else) dijalankan apabila kondisi bernilai False.
#
#  c. Pernyataan if-elif-else — digunakan ketika terdapat lebih dari dua kemungkinan kondisi. Python akan mengevaluasi kondisi secara berurutan dari atas ke bawah, dan hanya akan mengeksekusi satu blok kode pertama yang kondisinya bernilai True, kemudian keluar dari struktur percabangan tersebut.
#
#  d. Multiple if (beberapa if berdiri sendiri) — berbeda dengan if-elif-else, setiap pernyataan if pada bentuk ini dievaluasi secara independen dan tidak saling berkaitan. Akibatnya, lebih dari satu blok kode dapat dieksekusi sekaligus apabila lebih dari satu kondisi bernilai True.
#
#  e. Pernyataan match-case — merupakan struktur pattern matching yang diperkenalkan pada Python 3.10. Nilai suatu variabel dicocokkan dengan pola-pola (case) yang telah didefinisikan secara berurutan, dan blok kode pada case yang cocok pertama kali akan dieksekusi. Case _ berfungsi sebagai kondisi default apabila tidak ada pola yang cocok.
#
#  f. Operator logika and — digunakan untuk menggabungkan dua kondisi atau lebih, di mana keseluruhan ekspresi hanya akan bernilai True apabila semua kondisi yang digabungkan bernilai True.

# %% [markdown]
# ## 2.2 Kode Program
#
# 2.2.1 Program "if1_2611531005"

# %%
ipk_1005 = float(input("Input IPK Anda ="))

if ipk_1005 > 2.75:
    print("Anda Lulus Sangat Memuaskan dengan IPK" + str(ipk_1005))

print("Program Selesai")
# Out:
# Input IPK Anda =3.5
# Anda Lulus Sangat Memuaskan dengan IPK3.5
# Program Selesai

# %% [markdown]
# Penjelasan :
#
# 1. Baris 1 (ipk_1005 = float(input("Input IPK Anda ="))): Mengambil masukan IPK dari pengguna, mengubah tipe datanya menjadi angka desimal (float), lalu menyimpannya ke dalam variabel ipk_1005.
#
# 2. Baris 3–4 (if ipk_1005 > 2.75:): Memeriksa apakah nilai ipk_1005 lebih besar dari 2.75. Jika kondisi ini bernilai True (benar), program akan mencetak teks kelulusan beserta nilai IPK yang dikonversi kembali menjadi teks via str(). Jika bernilai False, baris ini akan dilewati.
#
# 3. Baris 6 (print("Program Selesai")): Mencetak penutup program. Karena ditulis di luar blok if (tanpa indentasi), perintah ini akan selalu dijalankan di akhir.

# %% [markdown]
# 2.2.2 Program "if2_2611531005"

# %%
ipk_1005 = float(input("Input IPK Anda ="))

if ipk_1005 > 2.75:
    print("Anda Lulus Sangat Memuaskan dengan IPK" + str(ipk_1005))
else:
    print("Anda Tidak Lulus")
print("Program Selesai")
# Out:
# Input IPK Anda =2.70
# Anda Tidak Lulus
# Program Selesai

# %% [markdown]
# Penjelasan:
#
# 1. Baris 1: ipk_1005 = float(input("Input IPK Anda ="))
# Input("Input IPK Anda ="): Menampilkan teks di layar dan mengambil masukan (input) dari pengguna dalam bentuk teks (string). float(...): Mengonversi teks input pengguna menjadi tipe data bilangan desimal (float), karena IPK umumnya bernilai desimal (seperti 3.25 atau 2.50).ipk_1005 = ...: Menyimpan hasil konversi desimal tersebut ke dalam variabel bernama ipk_1005.
#
# 2. Baris 3-4: if ipk_1005 > 2.75: dan perintah di dalamnya   if ipk_1005 > 2.75:: Blok pengecekan kondisi.
# Program memeriksa apakah nilai pada variabel ipk_1005 lebih besar dari 2.75. print("Anda Lulus Sangat Memuaskan dengan IPK" + str(ipk_1005)):Baris ini hanya dijalankan jika kondisi pada baris 3 bernilai True (benar). str(ipk_1005): Mengubah kembali nilai ipk_1005 dari angka (float) menjadi teks (string) agar bisa digabungkan dengan teks lainnya menggunakan operator +. Jika nilai IPK yang dimasukkan kurang dari atau sama dengan 2.75, baris ini akan dilompati (diabaikan).
#
# 3. Baris 6: print("Program Selesai")   Perintah ini ditulis tanpa indentasi (tidak menjorok ke dalam), yang menandakan bahwa baris ini berada di luar blok if. Teks "Program Selesai" akan selalu dicetak di layar pada akhir eksekusi, baik kondisi if terpenuhi maupun tidak.
#
#       Alur Eksekusi Program:
#
# 1. Skenario A (IPK > 2.75, misal: 3.5):Pengguna memasukkan 3.5.Kondisi 3.5 > 2.75 bernilai True.     Output:Anda Lulus Sangat Memuaskan dengan IPK 3.5
# Program Selesai
#
# 2. Skenario B (IPK > 2.75, misal: 2.5):Pengguna memasukkan 2.5.Kondisi 2.5 > 2.75 bernilai False. Maka blok if dilompati.
# Output: Program Selesai

# %% [markdown]
# 2.2.3 Program "multi_if1_2611531005"

# %%
umur_1005 = int(input("Input umur anda: "))
sim_1005 = input("Apakah Anda Sudah Punya SIM C (y/t): ")[0]

if umur_1005  >= 17 and sim_1005 == 'y':
    print("Anda sudah dewasa dan boleh bawa motor")

if umur_1005 >= 17 and sim_1005 != 'y':
    print("Anda sudah dewasa tapi tidak boleh bawa motor")

if umur_1005 < 17 and sim_1005 != 'y' :
    print("Anda belum cukup umur bawa motor")

if umur_1005 < 17 and sim_1005 == 'y':
    print("Anda belum cukup umur punya SIM")
# Out:
# Input umur anda: 19
# Apakah Anda Sudah Punya SIM C (y/t): t
# Anda sudah dewasa tapi tidak boleh bawa motor

# %% [markdown]
# Penjelasan:
#
# 1. Input Data dan Parsing (Baris 1-2)
#
#    a. Baris 1 (umur_1005 = int(...)): Mengambil masukan umur dari pengguna dan mengonversinya menjadi bilangan bulat (integer).
#
#    b. Baris 2 (sim_1005 = input(...)[0]): Mengambil masukan status SIM, lalu menggunakan indeks [0] untuk mengambil karakter pertama saja (misalnya mengambil 'y' dari jawaban "ya").
#
# 2. Pengecekan Kondisi dengan Multi-IF (Baris 4–14)
# Berbeda dengan struktur if-elif-else, pendekatan di kode ini menggunakan 4 blok if independen yang mutually exclusive (saling pilah):
#
#    a. Baris 4–5: Memeriksa apakah umur >=  17 DAN punya SIM (== 'y'). Jika True, mencetak: "Anda sudah dewasa dan boleh bawa motor".
#
#    b. Baris 7–8: Memeriksa apakah umur  >= 17 DAN tidak punya SIM (!= 'y'). Jika True, mencetak: "Anda sudah dewasa tapi tidak boleh bawa motor".
#
#    c. Baris 10–11: Memeriksa apakah umur < 17 DAN tidak punya SIM (!= 'y'). Jika True, mencetak: "Anda belum cukup umur bawa motor".
#
#    d. Baris 13–14: Memeriksa apakah umur < 17 DAN mengklaim punya SIM (== 'y'). Jika True, mencetak: "Anda belum cukup umur punya SIM".
#
# 3. Catatan: Meskipun program mengevaluasi keempat blok if satu per satu, hanya satu blok if yang akan bernilai True dan mencetak pesan ke layar karena seluruh kombinasinya sudah mencakup seluruh kemungkinan kondisi.

# %% [markdown]
# 2.2.4 Program "multi_if2_2611531005"

# %%
# Input dari user
total_belanja_1005 = float(input("Masukkan total belanja (Rp): "))

# Input dari status member ( mengecek apakah user mengetik 'y' atau 'ya')
input_member_1005 = input("Apakah anda member (y/t): ").strip().lower()
is_member_1005 = input_member_1005 in ["y", "ya"]

# Input status kode promo (mengecek apakah user mengetik 'y' atau 'ya')
input_promo_1005 = input("Apakah kode promo valid? (y/t):").strip().lower()
kode_promo_valid_1005 = input_promo_1005 in["y", "ya"]

total_diskon_persen_1005 = 0

if total_belanja_1005 > 1000000:
    total_diskon_persen_1005 +=10 #Diskon belanja besar

if is_member_1005:
    total_diskon_persen_1005 += 5 #Diskon member

if kode_promo_valid_1005:
    total_diskon_persen_1005 +=15 #Diskon voucher

#Menghitung nominal diskon dan total bayar
nominal_diskon_1005 = total_belanja_1005 * (total_diskon_persen_1005 / 100)
total_bayar_1005 = total_belanja_1005 - nominal_diskon_1005

#Output hasil
print("\n--- Rincian Pembayaran ---")
print(f"Total Diskon : {total_diskon_persen_1005}%(Rp{nominal_diskon_1005:,.0f})")
print(f"Total Bayar : Rp {total_bayar_1005: ,.0f}")

print(f"Total diskon yang anda dapatkan: {total_diskon_persen_1005}%")
# Output total diskon yang anda dapatkan : 30% jika belanja > 1juta, member, dan kode promo valid
# Out:
# Masukkan total belanja (Rp): 1500000
# Apakah anda member (y/t): y
# Apakah kode promo valid? (y/t):y
#
# --- Rincian Pembayaran ---
# Total Diskon : 30%(Rp450,000)
# Total Bayar : Rp  1,050,000
# Total diskon yang anda dapatkan: 30%

# %% [markdown]
# Penjelasan:
#
# 1. Input Data dan Validasi String (Baris 1–10)
#
#    a. Baris 2 (total_belanja_1005): Menerima input nominal total belanja dari pengguna dan mengonversinya menjadi angka desimal (float).
#
#    b. Baris 5–6 (is_member_1005): Menerima input status keanggotaan..strip().lower() digunakan untuk menghapus spasi liar dan mengubah huruf menjadi kecil.Operator in ["y", "ya"] mengecek apakah jawaban pengguna adalah "y" atau "ya", lalu menyimpannya sebagai nilai boolean (True atau False).
#
#    c. Baris 9–10 (kode_promo_valid_1005): Melakukan proses pembersihan teks (string handling) dan pengecekan yang sama untuk status validasi kode promo.
#
# 2. Akumulasi Diskon Bertingkat dengan Multi-IF (Baris 12–21)
#
#    a. Baris 12 (total_diskon_persen_1005 = 0): Menginisialisasi persentase diskon awal sebesar 0%.
#
#    b. Baris 14–15 (if total_belanja_1005 > 1000000:): Jika total belanja melebihi Rp 1.000.000, persentase diskon bertambah 10%.
#
#    c. Baris 17–18 (if is_member_1005:): Blok if independen (bukan elif) untuk mengecek status member. Jika bernilai True, diskon bertambah lagi 5%.
#
#    d. Baris 20–21 (if kode_promo_valid_1005:): Blok if independen untuk mengecek voucher promo. Jika bernilai True, diskon bertambah lagi 15%.
#
#    e. Catatan Logika: Karena menggunakan if terpisah (bukan elif), seluruh kondisi akan diperiksa satu per satu sehingga semua diskon yang memenuhi syarat dapat terakumulasi (ditumpuk) hingga maksimal 30%.
#
# 3. Perhitungan Nominal Pembayaran (Baris 23–25)
#
#    a. Baris 24 (nominal_diskon_1005): Menghitung jumlah potongan harga dalam rupiah dengan rumus:   total_belanja x (total_diskon_persen / 100).
#
#    b. Baris 25 (total_bayar_1005): Menghitung total tagihan akhir dengan mengurangi total belanja awal dengan nominal diskon.
#
# 4. Menampilkan Output Rincian Pembayaran (Baris 28–32)
#
#    a. Baris 28–30: Mencetak header rincian pembayaran, total persentase beserta nominal rupiah diskon, dan total biaya yang harus dibayar. Format :, .0f digunakan untuk menampilkan angka desimal tanpa koma dan memberi pemisah ribuan (thousand separator).
#
#    b. Baris 32: Mencetak kembali ringkasan total persentase diskon yang berhasil didapatkan oleh pengguna.

# %% [markdown]
# 2.2.5 Program "if_elif_else_2611531005"

# %%
umur_1005 = int(input("Input umur anda: "))
sim_1005 = input("Apakah Anda Sudah Punya SIM C: ")[0]

if umur_1005 >= 17 and sim_1005 == 'y':
    print("Anda sudah dewasa dan boleh bawa motor")
elif umur_1005 >= 17 and sim_1005 != 'y':
     print("Anda sudah dewasa tetapi tidak boleh bawa motor")
elif umur_1005 < 17 and sim_1005 =='y':
     print("Anda belum cukup umur punya SIM")
else:
     print("Anda belum cukup umur dan tidak boleh bawa motor")
print("Program Selesai")
# Out:
# Input umur anda: 18
# Apakah Anda Sudah Punya SIM C: y
# Anda sudah dewasa dan boleh bawa motor
# Program Selesai

# %% [markdown]
# Penjelasan:
#
# 1. Baris 1: umur_1005 = int(input("Input umur anda: ")) Mengambil masukan umur dari pengguna melalui input(). Fungsi int(...) mengubah teks masukan menjadi tipe data bilangan bulat (integer) yang kemudian disimpan dalam variabel umur_1005.
#
# 2. Baris 2: sim_1005 = input("Apakah Anda Sudah Punya SIM C: ")[0]
# Menerima input status kepemilikan SIM dari pengguna.   Penggunaan [0] (string indexing) berfungsi untuk mengambil hanya karakter pertama dari jawaban pengguna. Misalnya, jika pengguna mengetik "ya", yang diambil dan disimpan ke variabel sim_1005 hanyalah huruf 'y'.
#
# 3. Baris 4-5: if umur_1005 >= 17 and sim_1005 == 'y':
# Kondisi 1: Memeriksa apakah umur pengguna >= 17 tahun DAN jawaban SIM bernilai 'y'. Jika kedua syarat terpenuhi, program mencetak: "Anda sudah dewasa dan boleh bawa motor".
#
# 4. Baris 6-7: elif umur_1005 >= 17 and sim_1005 != 'y':
# Kondisi 2: Memeriksa apakah umur pengguna >= 17 tahun DAN jawaban SIM bukan 'y'. Jika syarat ini terpenuhi, program mencetak: "Anda sudah dewasa tetapi tidak boleh bawa motor".
#
# 5. Baris 8-9: elif umur_1005 < 17 and sim_1005 == 'y':
# Kondisi 3: Memeriksa apakah umur pengguna < 17 tahun DAN jawaban SIM bernilai 'y'. Kondisi ini menangani kasus tidak logis di mana seseorang belum 17 tahun tetapi mengaku punya SIM. Jika syarat terpenuhi, program mencetak: "Anda belum cukup umur punya SIM".
#
# 6. Baris 10-11: else:  Kondisi Cadangan: Dijalankan jika seluruh kondisi di atas bernilai False (artinya umur  17 tahun DAN jawaban SIM bukan 'y'). Program akan mencetak: "Anda belum cukup umur dan tidak boleh bawa motor".
#
# 7. Baris 12: print("Program Selesai") Berada di luar blok percabangan (tanpa indentasi). Teks "Program Selesai" akan selalu dicetak pada bagian akhir setelah evaluasi kondisi selesai dilakukan.

# %% [markdown]
# 2.2.6 Program "match_case1_2611531005"

# %%
bulan_1005 = int(input("masukkan angka bulan (1-12): "))

match bulan_1005:
    case 1:
        print("Januari")
    case 2:
        print("Februari")
    case 3:
        print("Maret")
    case 4:
        print("April")
    case 5:
        print("Mei")
    case 6:
        print("Juni")
    case 7:
        print("Juli")
    case 8:
        print("Agustus")
    case 9:
        print("September")
    case 10:
        print("Oktober")
    case 11:
        print("November")
    case 12:
        print("Desember")
    case _:
        print("Angka tidak valid")
# Out:
# masukkan angka bulan (1-12): 12
# Desember

# %% [markdown]
# Penjelasan:
#
# 1. Baris 1 (bulan_1005 = int(input("masukkan angka bulan (1-12): ")))
# Mengambil masukan angka dari pengguna, mengonversinya menjadi bilangan bulat (integer), lalu menyimpannya ke dalam variabel bulan_1005.
#
# 2. Baris 3 (match bulan_1005:): Membuka struktur penyeleksian kondisi match-case untuk mengevaluasi nilai yang tersimpan di dalam variabel bulan_1005.
#
# 3. Baris 4–27 (case 1: hingga case 12:): Menjodohkan nilai bulan_1005 secara langsung dengan angka 1 sampai 12:
#
#    a. case 1: Mencetak "Januari"
#
#    b. case 2: Mencetak "Februari"
#
#    c. case 3: Mencetak "Maret"
#
#    d. case 4: Mencetak "April"
#
#    e. case 5: Mencetak "Mei"
#
#    f. case 6: Mencetak "Juni"
#
#    g. case 7: Mencetak "Juli"
#
#    h. case 8: Mencetak "Agustus"
#
#    i. case 9: Mencetak "September"
#
#    j. case 10: Mencetak "Oktober"
#
#    k. case 11: Mencetak "November"
#
#    l. case 12: Mencetak "Desember"
#
# 4. Baris 28–29 (case _: dan print("Angka tidak valid"))
# Berfungsi sebagai kondisi default (wildcard). Karakter garis bawah (_) akan menangkap seluruh nilai masukan yang tidak cocok dengan angka 1 sampai 12 (misalnya angka 0, 13, atau -5) dan mencetak pesan "Angka tidak valid".
#
# 5. Catatan Alur: Match-case bekerja mirip seperti switch-case pada bahasa pemrograman lain. Program hanya mengeksekusi satu cabang case yang nilainya cocok secara persis dengan variabel yang dievaluasi.

# %% [markdown]
# 2.2.7 Program "nilai_2611531005"

# %%
nilai_1005 = int(input("inputkan nilai angka= "))

if nilai_1005 >=81:
    print("A")
elif nilai_1005 >=70:
    print("B")
elif nilai_1005 >=60:
    print("C")
elif nilai_1005 >= 50:
    print("D")
else:
    print("E")
# Out:
# inputkan nilai angka= 54
# D

# %% [markdown]
# Penjelasan:
#
# 1. Baris 1 (nilai_1005 = int(input("inputkan nilai angka= "))): Mengambil masukan nilai angka dari pengguna, mengonversinya ke bentuk bilangan bulat (integer), lalu menyimpannya di variabel nilai_1005.
#
# 2. Baris 3–4 (if nilai_1005 >= 81: print("A")): Memeriksa apakah nilai >= 81. Jika True, program mencetak "A" lalu selesai.
#
# 3. Baris 5–6 (elif nilai_1005 >= 70: print("B")): Mengecek apakah nilai berada di rentang 70 - 80. Jika True, program mencetak "B".
#
# 4. Baris 7–8 (elif nilai_1005 >= 60: print("C")): Mengecek apakah nilai berada di rentang 60 - 69. Jika True, program mencetak "C".
#
# 5. Baris 9–10 (elif nilai_1005 >= 50: print("D")): Mengecek apakah nilai berada di rentang 50 - 59. Jika True, program mencetak "D".
#
# 6. Baris 11–12 (else: print("E")): Dijalankan jika seluruh kondisi di atas bernilai False (artinya nilai < 50). Program mencetak "E".

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="images/Soal_tugas 4.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "tugas4_2611531005"

# %%
print("=== SISTEM LOKET ALPRO ADVENTURE PARK ===")

# 1. Input Data Pengunjung Utama
nama_1005 = input("Masukkan Nama Pengunjung        : ")
umur_1005 = int(input("Input umur anda                 : "))
sim_1005 = input("Apakah Anda Sudah Punya SIM C (y/t): ")[0].lower()

# Status Kepemilikan SIM
status_sim_1005 = "Punya" if sim_1005 == 'y' else "Tidak Punya"

#Output biodata pengunjung
print("\n-----------------------------------------")
print("--- BIODATA PENGUNJUNG ---")
print(f"Nama Pengunjung  : {nama_1005}")
print(f"Umur             : {umur_1005} tahun")
print(f"Status SIM C     : {status_sim_1005}")

# Tampilkan Daftar Paket Wahana untuk Masukan Pengunjung
print("\nPilihan Paket Wahana (1-5):")
print("  1. Safari Rimba         (Rp 50,000)")
print("  2. Arung Jeram          (Rp 75,000)")
print("  3. Motor ATV Ekstrim    (Rp 120,000)")
print("  4. Roller Coaster Kilat (Rp 100,000)")
print("  5. All-Access VIP       (Rp 220,000)")

paket_1005 = int(input("Masukkan nomor paket (1-5)      : "))
jumlah_tiket_1005 = int(input("Masukkan jumlah tiket           : "))

# Penerapan IF tunggal untuk validasi kuota tiket
if jumlah_tiket_1005 <= 0:
    print("Peringatan: Kuota tiket tidak valid!")

input_member_1005 = input("Apakah Anda member? (y/t)        : ").strip().lower()
is_member_1005 = input_member_1005 in [ "y", "ya"]

input_promo_1005 = input("Apakah kode promo valid? (y/t)  : ").strip().lower()
kode_promo_valid_1005 = input_promo_1005 in [ "y", "ya"]

# 2. Pemilihan Wahana Menggunakan match-case
harga_satuan_1005 = 0
nama_wahana_1005 = ""

match paket_1005:
    case 1:
        nama_wahana_1005 = "Wahana Safari Rimba"
        harga_satuan_1005 = 50000
    case 2:
        nama_wahana_1005 = "Wahana Arung Jeram"
        harga_satuan_1005 = 75000
    case 3:
        nama_wahana_1005 = "Wahana Motor ATV Ekstrim"
        harga_satuan_1005 = 120000
    case 4:
        nama_wahana_1005 = "Wahana Roller Coaster Kilat"
        harga_satuan_1005 = 100000
    case 5:
        nama_wahana_1005 = "Wahana All-Access VIP"
        harga_satuan_1005 = 220000
    case _:
        print("\nPaket wahana tidak valid!")
        harga_satuan_1005 = 0


# 3. Validasi Izin Kendali Wahana Menggunakan if-elif-else
print("\n--- KELAYAKAN PENGENDARA WAHANA ---")
if paket_1005 == 3:
       if umur_1005 >= 17 and sim_1005 == 'y':
           status_akses_1005 = "Anda sudah dewasa dan boleh mengendarai ATV sendiri."
       elif umur_1005 >= 17 and sim_1005 != 'y':
           status_akses_1005 = "Anda sudah dewasa tetapi tidak boleh bawa motor ATV (wajib didampingi instruktur)."
       elif umur_1005 < 17 and sim_1005 == 'y':
           status_akses_1005 = "Identitas tidak valid: Belum cukup umur memiliki SIM."
       else:
           status_akses_1005 = "Anda belum cukup umur dan tidak boleh bawa motor ATV."
else:
       if umur_1005 >= 10:
           status_akses_1005 = "Anda memenuhi syarat umur untuk wahana ini."
       else:
           status_akses_1005 = "Anda belum cukup umur untuk wahana ini."

print(f"Status Akses: {status_akses_1005}")

    # 4. Akumulasi Diskon Bertingkat Menggunakan Multi-IF Terpisah
subtotal_1005 = harga_satuan_1005 * jumlah_tiket_1005
total_diskon_persen_1005 = 0

if subtotal_1005 >= 200000:
        total_diskon_persen_1005 += 10  # Diskon Belanja Besar

if is_member_1005:
        total_diskon_persen_1005 += 5   # Diskon Member

if kode_promo_valid_1005:
        total_diskon_persen_1005 += 15  # Diskon Voucher Promo

if jumlah_tiket_1005 >= 5:
        total_diskon_persen_1005 += 5   # Diskon Tambahan Rombongan

    # 5. Menghitung Nominal Diskon dan Total Bayar
nominal_diskon_1005 = subtotal_1005 * (total_diskon_persen_1005 / 100)
total_bayar_1005 = subtotal_1005 - nominal_diskon_1005

    # Evaluasi Bonus Audit Menggunakan if-else
if total_bayar_1005 > 300000:
        catatan_layanan_1005 = "Selamat! Anda berhak mendapatkan Souvenir Gratis."
else:
        catatan_layanan_1005 = "Terima kasih telah berkunjung."

    # OUTPUT SELANJUTNYA: RINCIAN PEMBAYARAN
print("\n--- RINCIAN PEMBAYARAN ---")
print(f"Paket Dipilih    : Paket {paket_1005} ({nama_wahana_1005})")
print(f"Jumlah Tiket     : {jumlah_tiket_1005} tiket")
print(f"Status Member    : {input_member_1005}")
print(f"Kode Promo Valid : {input_promo_1005}")
print(f"Wahana Dipilih   : {nama_wahana_1005}")
print(f"Jumlah Tiket     : {jumlah_tiket_1005} tiket")
print(f"Subtotal Belanja : Rp {subtotal_1005:,.0f}")
print(f"Total Diskon     : {total_diskon_persen_1005}% (Rp {nominal_diskon_1005:,.0f})")
print(f"Total Bayar      : Rp {total_bayar_1005:,.0f}")
print(f"Catatan Layanan  : {catatan_layanan_1005}")

print("Program Selesai")
# Out:
# === SISTEM LOKET ALPRO ADVENTURE PARK ===
# Masukkan Nama Pengunjung        : Fathimah Syahida
# Input umur anda                 : 18
# Apakah Anda Sudah Punya SIM C (y/t): y
#
# -----------------------------------------
# --- BIODATA PENGUNJUNG ---
# Nama Pengunjung  : Fathimah Syahida
# Umur             : 18 tahun
# Status SIM C     : Punya
#
# Pilihan Paket Wahana (1-5):
#   1. Safari Rimba         (Rp 50,000)
#   2. Arung Jeram          (Rp 75,000)
#   3. Motor ATV Ekstrim    (Rp 120,000)
#   4. Roller Coaster Kilat (Rp 100,000)
#   5. All-Access VIP       (Rp 220,000)
# Masukkan nomor paket (1-5)      : 4
# Masukkan jumlah tiket           : 2
# Apakah Anda member? (y/t)        : y
# Apakah kode promo valid? (y/t)  : yy
#
# --- KELAYAKAN PENGENDARA WAHANA ---
# Status Akses: Anda memenuhi syarat umur untuk wahana ini.
#
# --- RINCIAN PEMBAYARAN ---
# Paket Dipilih    : Paket 4 (Wahana Roller Coaster Kilat)
# Jumlah Tiket     : 2 tiket
# Status Member    : y
# ...

# %% [markdown]
# Penjelasan:
#
# 1. Input Data & Biodata Pengunjung (Baris 1–16)
#
#    a. Menerima Input Utama: Meminta input nama (nama_1005), umur (umur_1001), dan kepemilikan SIM C (sim_1005). Karakter pertama input SIM diambil dan diubah ke huruf kecil (.lower()).
#
#    b.Ternary Operator: Mengatur variabel status_sim_1005 menjadi "Punya" jika input berawalan 'y', dan "Tidak Punya" jika selain itu.
#
#    c. Mencetak Biodata: Menampilkan ringkasan data awal pengunjung.
#
# 2. Pemilihan Paket & Validasi Awal (Baris 18–38)
#
#    a.Menampilkan Menu: Menampilkan 5 pilihan paket wahana beserta harganya masing-masing.
#
#    b.Input Pesanan: Meminta nomor paket (paket_1005) dan jumlah tiket (jumlah_tiket_1005).
#
#    c. Validasi Kuota Tiket: Menggunakan if tunggal untuk memberikan peringatan jika jumlah tiket yang diinput <= 0.
#
#    d. Cek Member & Promo: Meminta konfirmasi status member dan kode promo. Nilai dikonversi menjadi tipe data boolean (True/False) dengan memeriksa apakah input bernilai "y" atau "ya".
#
# 3. Penentuan Wahana & Harga (match-case) (Baris 39–62)
#
#    a. Menggunakan fitur match-case untuk menetapkan nama wahana (nama_wahana_1005) dan harga per tiket (harga_satuan_1005) sesuai pilihan nomor paket:
#
#      Paket 1: Safari Rimba (Rp 50.000)
#      Paket 2: Arung Jeram (Rp 75.000)
#      Paket 3: Motor ATV Ekstrim (Rp 120.000)
#      Paket 4: Roller Coaster Kilat (Rp 100.000)
#      Paket 5: All-Access VIP (Rp 220.000)
#      Default (case _): Menampilkan pesan tidak valid jika pilihan di luar 1–5.
#
# 4. Validasi Kelayakan Pengendara Wahana (Baris 64–81)
#
#    a. Khusus Paket 3 (ATV): Memerlukan syarat ketat:
#
#       Umur >= 17 tahun & punya SIM C = Boleh mengendarai ATV sendiri.
#       Umur >= 17 tahun & tidak punya SIM C = Wajib didampingi instruktur.
#       Umur < 17 tahun & mengaku punya SIM C = Terdeteksi identitas tidak valid.
#       Umur < 17 tahun & tidak punya SIM C = Tidak boleh mengendarai ATV.
#
#    b. Paket Lainnya (Selain ATV): Hanya mengecek batas minimal umur $\ge 10$ tahun.
#
# 5. Akumulasi Diskon Bertingkat (Baris 83–98)
#
#    a. Menghitung subtotal_1005 (harga_satuan x jumlah_tiket).
#
#    b. Mengakumulasikan persentase diskon (total_diskon_persen_1005)
#    Menggunakan beberapa struktur if terpisah:
#
#       Subtotal >= Rp 200.000 = Diskon +10%
#       Status Member = True = Diskon +5%
#       Kode Promo Valid = True = Diskon +15%
#       Jumlah Tiket >= 5 = Diskon +5%
#
# 6. Perhitungan Total Bayar & Rincian Pembayaran (Baris 99–122)
#
#    a. Menghitung nominal diskon dalam Rupiah dan total bayar akhir (subtotal - nominal_diskon)
#
#    b. Menggunakan if-else untuk mengecek apakah total_bayar_1005 > Rp 300.000 untuk memberikan bonus souvenir gratis.
#
#    c. Menampilkan ringkasan nota transaksi lengkap beserta format angka Rupiah sebelum program selesai.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# 1. Struktur percabangan pada Python
# Mulai dari if tunggal, if-else, if-elif-else, multiple if, hingga match-case, masing-masing memiliki fungsi dan konteks penggunaan yang berbeda, sehingga pemilihan bentuk percabangan yang tepat sangat memengaruhi kebenaran logika dan efisiensi suatu program.
#
# 2. Pernyataan if tunggal cocok digunakan apabila hanya ada satu kemungkinan aksi yang perlu dijalankan, sedangkan if-else diperlukan apabila terdapat dua kemungkinan hasil yang keduanya perlu ditangani secara eksplisit, seperti pada studi kasus pengecekan kelulusan berdasarkan IPK.
#
# 3. Struktur if-elif-else paling tepat digunakan pada kondisi-kondisi yang saling eksklusif dan bertingkat, seperti pada penentuan status kelayakan mengendarai motor dan penentuan grade nilai, karena Python akan berhenti mengevaluasi begitu menemukan kondisi pertama yang bernilai True sehingga lebih efisien.
#
# 4. Pendekatan multiple if (beberapa if berdiri sendiri) diperlukan ketika kondisi-kondisi yang dievaluasi tidak saling eksklusif dan memungkinkan lebih dari satu blok kode dieksekusi sekaligus, sebagaimana terlihat pada studi kasus perhitungan diskon belanja di mana beberapa jenis diskon dapat diakumulasikan sekaligus.
#
# 5. Struktur match-case memberikan solusi yang lebih ringkas dan mudah dibaca dibandingkan if-elif-else yang panjang, khususnya ketika suatu variabel perlu dicocokkan dengan banyak nilai diskrit, seperti pada studi kasus penentuan nama bulan.
#
# 6. Operator logika and berperan penting dalam menggabungkan lebih dari satu syarat menjadi satu kondisi tunggal, sehingga suatu blok kode hanya akan dieksekusi apabila seluruh syarat yang digabungkan terpenuhi secara bersamaan.
#
# 7. Melalui praktikum ini, mahasiswa telah berhasil memahami dan mempraktikkan berbagai bentuk struktur percabangan pada Python untuk menyelesaikan beragam studi kasus, mulai dari pengecekan kelulusan, syarat berkendara, penentuan nama bulan, perhitungan diskon, hingga penentuan grade nilai.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation. (2023). Python 3.11.9 documentation.
#
# [2] Microsoft. (2024). Visual Studio Code Documentation. Diakses dari https://code.visualstudio.com/docs
#
# [3] GitHub, Inc. (2024). GitHub Docs. Diakses dari https://docs.github.com
#
# [4] Python Software Foundation. (2025). The Python Tutorial: More Control Flow Tools. Diakses dari https://docs.python.org/3/tutorial/controlflow.html
#
# [5] Python Software Foundation. (2025). PEP 634 – Structural Pattern Matching: Specification. Diakses dari https://peps.python.org/pep-0634/
#
# [6] Downey, A. (2015). Think Python: How to Think Like a Computer Scientist (2nd ed.). O'Reilly Media.
# Lutz, M. (2013). Learning Python (5th ed.). O'Reilly Media.
#
# [7] Matthes, E. (2019). Python Crash Course: A Hands-On, Project-Based Introduction to Programming (2nd ed.). No Starch Press.
